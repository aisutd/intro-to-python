# %% [markdown]
# Don't forget to use the link you see on the slides to ask questions! \\
# You got this 		(*꒦ິ꒳꒦ີ)b

# %%
print("Welcome to the first AIS Workshop of the semester!!!!!!!!")
# Out:
# Welcome to the first AIS Workshop of the semester!!!!!!!!

# %% [markdown]
# # Commenting
# ---

# %%
# Thanks for coming!

# %% [markdown]
# # Printing
# ---

# %%
'whoosh'
# Out:
# 'whoosh'

# %%
print('whoosh')
# Out:
# whoosh

# %% [markdown]
# #Arithmetic Operators
#
# ---

# %% [markdown]
# ![arithmetic operators.png](data:image/png;base64,...)

# %%
16 ** 2 / 4
# Out:
# 64.0

# %%
1816 * 1.609
# Out:
# 2921.944

# %% [markdown]
# # Variables
# ---

# %%
miles = 1816
ratio = 1.609
kilometers = miles * ratio
kilometers
# Out:
# 2921.944

# %%
miles = 28
kilometers = ___ * ___
kilometers
# Out:
# 4096.0

# %% [markdown]
# # Strings
# ---

# %%
x = "Artifical"
y = "Intelligence"
x + " " + y
# Out:
# 'Artifical Intelligence'

# %%
x = "dallas"
x = x.upper()
print(x)

y = "UNIVERSITY OF TEXAS AT "
y = y.lower()
print(y)

print(y + x)
# Out:
# DALLAS
# university of texas at
# university of texas at DALLAS

# %%
x = "dallas"
y = "UNIVERSITY OF TEXAS AT "

print(y.lower() + x.upper())
# Out:
# university of texas at DALLAS

# %%
dir('str')

# %% [markdown]
# # Types
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
integer = 21
decimal = 3.14
string = "ʕ•́ᴥ•̀ʔ"
boolean = True
none = None

print(str(integer) + " is of " + str(type(integer)))
print(str(decimal) + " is of " + str(type(decimal)))
print(string + " is of " + str(type(string)))
print(str(boolean) + " is of " + str(type(boolean)))
print(str(none) + " is of " + str(type(none)))
# Out:
# 21 is of <class 'int'>
# 3.14 is of <class 'float'>
# ʕ•́ᴥ•̀ʔ is of <class 'str'>
# True is of <class 'bool'>
# None is of <class 'NoneType'>

# %%
x = 10   # This is an integer
y = "20" # This is a string
x + y
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-2b237bb4c6cb> in <module>()
#       1 x = 10   # This is an integer
#       2 y = "20" # This is a string
# ----> 3 x + y
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
x = "10"
y = "20"
x + y

# %%
x = 6
x = (x * 446) // 63
"The answer to Life, the Universe and Everything is " + str(x)

# %%
str1 = "I really like the number "
str2 = 9
str3 = ", it's really nice"

print(str1 + str2 + str3)

# %% [markdown]
# # Comparison Operators
# ---
# | Operation    | Output |
# | ----------- | ----------- |
# | x == y    |  True if x **equals** y       |
# | x != y   | True if x **does not equal** y     |
# | x < y | True if x is **less than** y|
# | x > y | True if x is **more than** y|
# | x <= y | True if x is **less than or equal to** y|
# | x >= y | True if x is **more than or equal to** y|

# %%
x = 5   # assigns 5 to the variable x
x == 5  # check if value of x is 5

# %%
x > 7

# %%
43 != 42      # True!

20 == 21      # 
21 != 20      # 
10 < 18       # 
10.2 > 10.1   # 
19 <= 20      # 
22 >= 28      #

# %% [markdown]
# # Logical Operators
# ---
# | Operation    | Result |
# | ----------- | ----------- |
# | x or y   |  True if **at least one** is true       |
# | x and y  | True only if **both** are true   |
# | not x | True only if x is false (flip flops it) |

# %%
False or True      # True
False and True     # False
True and True      # True
not False and True # True
not not not not not not not not False or True # True
# Out:
# True

# %%
True and True               # 
False and not True          # 
19 >= 21 and 29 < 10        # 
8 == 7 or 29 < 18           # 
not not True and not False  #
# Out:
# True

# %%
x = 14
# check if x is within the range 10..20

x __ 10 and x __ 20
# Out:
#   File "<ipython-input-38-15ad1748948b>", line 4
#     x __ 10 and x __ 20
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# # If/Else
# ---

# %%
x = True
if x:
  print("Executing if")
else:
  print("Executing else")
print("This always prints")

# %%
x = 10
if x % 2 == 0:
  print(str(x) + " is even!")
  if x % 5 == 0:
    print(str(x) + ' is divsible by 5!')
  else:
    print(str(x) + " is not divisible by 5!")
else:
  print(str(x) + ' is odd')
print('this has no indentation so it always runs')
# Out:
# 10 is even!
# 10 is divsible by 5!
# this has no indentation so it always runs

# %% [markdown]
# * if x % 2 == 0:
#     * print(str(x) + “ is even!”)
#     * if x % 5 == 0:
#         * print(str(x) + “ is divisible by 5!”)
#     * else:
#         * print(str(x) + “ is not divisible by 5!”)
# * else:
#     * print(str(x) + “ is odd”)

# %%
purchase_price = float(input("Price at which you have purchased bitcoins: "))
current_price = float(input("Current price of the bitcoins: "))

if current_price < purchase_price * 0.9:
  print("Don't sell")
  print("You will lose " + str(purchase_price - current_price) + "$ per bitcoin")
elif current_price > purchase_price * 1.2:
  print("You should sell")
  print("You will make " + str(current_price - purchase_price) + "$ per bitcoin")
else:
  print("The price hasn't really changed since you bought them")
# Out:
# Price at which you have purchased bitcoins: 21
# Current price of the bitcoins: 2000
# you should prob sell
# You will make 1979.0$ per bitcoin

# %%
purchase_price = float(input("Price at which you have purchased bitcoins: "))
current_price = float(input("Current price of the bitcoins: "))

if current_price > purchase_price * 0.9:
  print("Don't sell")
  print("You will lose " + str(purchase_price - current_price) + "$ per bitcoin")
elif current_price > purchase_price * 1.2:
  print("You should sell")
  print("You will make " + str(current_price - purchase_price) + "$ per bitcoin")
else:
  print("The price hasn't really changed since you bought them")

# %% [markdown]
# Whew, we finally got through all of that!
# Now you know all the basics of Python \\
# Next up, Data Structures$^{\text{yay!!!!!}}$

# %% [markdown]
# # Lists
# ---

# %% [markdown]
# ```
# list = [val1, val2, val3]
# ```

# %%
fruits = ["apple", "tomato", "persimmon", "orange"]
print(type(fruits))
print(fruits)
# Out:
# <class 'list'>
# ['apple', 'tomato', 'persimmon', 'orange']

# %%
fruits[1]
# Out:
# 'tomato'

# %%
fruits[3]

# %%
fruits[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-27-b8c91da6ba3a> in <module>()
# ----> 1 fruits[4]
#
# IndexError: list index out of range

# %%
len(fruits)
# Out:
# 4

# %%
fruits[1] = "peach"
print(fruits)

# %%
fruits.append("lime")   # add new item to end of list
print(fruits)
fruits.remove("orange") # remove orange from list ;-;
print(fruits)

# %%
nums = list(range(10))
print(nums)

# %%
nums = list(range(0,100,5))
print(nums)

# %%
print(len(nums))  # number of items in the list
print(max(nums))  # the maximum value within the list
print(min(nums))  # the minimum value within the list

# %%
mixed = [3, "Two", True, None, ["huh??"]]
print(mixed)

# %%
# Make the food list here!

# %% [markdown]
# # Tuples
# ---

# %% [markdown]
# ```
# tuple = (val1, val2, val3)
# ```

# %%
fruits = ("apple", "tomato", "persimmon", "orange")
print(type(fruits))
print(fruits)
# Out:
# <class 'tuple'>
# ('apple', 'tomato', 'persimmon', 'orange')

# %%
fruits[1] = "cherry"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-a5d5f06035fc> in <module>()
# ----> 1 fruits[1] = "cherry"
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # Dictionaries
# ---

# %% [markdown]
# ```
# mydict = {key1: val1, key2: val2}
# ```

# %%
days = {"Monday": "Diluain", "Tuesday": "Dimairt", 
        "Wednesday": "Diciadain", "Thursday": "Diardaoin", 
        "Friday": "Dihaoine"}
print(type(days))
print(days)
# Out:
# <class 'dict'>
# {'Monday': 'Diluain', 'Tuesday': 'Dimairt', 'Wednesday': 'Diciadain', 'Thursday': 'Diardaoin', 'Friday': 'Dihaoine'}

# %%
days["Friday"]
# Out:
# 'Dihaoine'

# %%
days["Saturday"] = "Disathairne"
print(days)
del days["Monday"] # I hate mondays
print(days)

# %%
# Make the song list here!

# %% [markdown]
# # Sets
# ---

# %% [markdown]
# ```
# set = {val1, val2, val3}
# ```

# %%
y = {1, 2, 3}

y
# Out:
# {1, 2, 3}

# %%
y[1] = 200
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-3d679794c0a8> in <module>()
# ----> 1 y[1] = 200
#
# TypeError: 'set' object does not support item assignment

# %% [markdown]
# # For Loops
# ---

# %%
fruits = ["apple", "tomato", "persimmon", "orange", "mango", "kiwi", "coconut",  
          "strawberry", "banana", "lychee", "papaya", "blueberry"] 

# it took me forever to come up with 12 fruits :(

print("The fruit " + str(fruits[0]) + " has index " + str(fruits.index(fruits[0])))
print("The fruit " + str(fruits[1]) + " has index " + str(fruits.index(fruits[1])))
print("The fruit " + str(fruits[2]) + " has index " + str(fruits.index(fruits[2])))
print("The fruit " + str(fruits[3]) + " has index " + str(fruits.index(fruits[3])))
print("The fruit " + str(fruits[4]) + " has index " + str(fruits.index(fruits[4])))
print("The fruit " + str(fruits[5]) + " has index " + str(fruits.index(fruits[5])))
print("The fruit " + str(fruits[6]) + " has index " + str(fruits.index(fruits[6])))
print("The fruit " + str(fruits[7]) + " has index " + str(fruits.index(fruits[7])))
print("The fruit " + str(fruits[8]) + " has index " + str(fruits.index(fruits[8])))
print("The fruit " + str(fruits[9]) + " has index " + str(fruits.index(fruits[9])))
print("The fruit " + str(fruits[10]) + " has index " + str(fruits.index(fruits[10])))
print("The fruit " + str(fruits[11]) + " has index " + str(fruits.index(fruits[11])))
# Out:
# The fruit apple has index 0
# The fruit tomato has index 1
# The fruit persimmon has index 2
# The fruit orange has index 3
# The fruit mango has index 4
# The fruit kiwi has index 5
# The fruit coconut has index 6
# The fruit strawberry has index 7
# The fruit banana has index 8
# The fruit lychee has index 9
# The fruit papaya has index 10
# The fruit blueberry has index 11

# %%
fruits = ["apple", "tomato", "persimmon", "orange", "mango", "kiwi", "coconut",  
          "strawberry", "banana", "lychee", "papaya", "blueberry"] 

for fruit in fruits:
  print("The fruit " + fruit + " has index " + str(fruits.index(fruit)))
# Out:
# The fruit apple has index 0
# The fruit tomato has index 1
# The fruit persimmon has index 2
# The fruit orange has index 3
# The fruit mango has index 4
# The fruit kiwi has index 5
# The fruit coconut has index 6
# The fruit strawberry has index 7
# The fruit banana has index 8
# The fruit lychee has index 9
# The fruit papaya has index 10
# The fruit blueberry has index 11

# %%
for num in range(10):
  squared = num ** 2
  print(str(num) + " squared is " + str(squared))
# Out:
# 0 squared is 0
# 1 squared is 1
# 2 squared is 4
# 3 squared is 9
# 4 squared is 16
# 5 squared is 25
# 6 squared is 36
# 7 squared is 49
# 8 squared is 64
# 9 squared is 81

# %% [markdown]
# # While Loops
# ---

# %%
n = 0
while True:
  print("n is " + str(n))
  n = n + 1

# %%
n = 0
while n < 5:
  print("n is " + str(n))
  n = n + 1

print("Finished while loop")
# Out:
# n is 0
# n is 1
# n is 2
# n is 3
# n is 4
# Finished while loop

# %% [markdown]
# # Functions
# ---

# %% [markdown]
# ```python
# def functionName(argument1, argument2, ... argumentN):
#   statements ..
#   ..
#   ..
#
#   return value
# ```

# %%
def printNum(num):
  print("My favorite number is " + str(num))

printNum(9)
printNum(7)
printNum(68)
# Out:
# My favorite number is 9
# My favorite number is 7
# My favorite number is 68

# %%
# implement the function here

def add(_, _):

  return ____

a = 2
b = 4
c = add(_, _)
print(str(a) + " + " + str(b) + " = " + str(c))
# Out:
# 2 + 4 = 6

# %% [markdown]
# [click me for excerises!](https://intro.nasuno.me)
